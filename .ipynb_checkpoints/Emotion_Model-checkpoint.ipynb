# %%
import matplotlib.pyplot as plt
from glob import glob
import cv2
import random
import os
# %matplotlib inline
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Input, Dropout, Flatten, Conv2D
from tensorflow.keras.layers import BatchNormalization, Activation, MaxPooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.utils import plot_model

from IPython.display import SVG, Image
import tensorflow as tf
print("Tensorflow version:", tf.__version__)
# Out:
# WARNING:tensorflow:From C:\Users\vnr_i\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Tensorflow version: 2.15.0

# %%
images=glob("train/**/**")
for i in range(9):
    image=random.choice(images)
    plt.figure(figsize=(12,12))
    plt.subplot(331+i)
    plt.imshow(cv2.imread(image));plt.axis('off')

# %%
img_size=48
batch_size=64
datagen_train=ImageDataGenerator()
train_generator=datagen_train.flow_from_directory("train/",target_size=(img_size,img_size), color_mode="grayscale", batch_size=batch_size, class_mode="categorical", shuffle=True)
datagen_validation=ImageDataGenerator()
validation_generator=datagen_train.flow_from_directory("test/",target_size=(img_size,img_size), color_mode="grayscale", batch_size=batch_size, class_mode="categorical", shuffle=True)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7175 images belonging to 7 classes.

# %%
def Convolution(input_tensor, filters, kernel_size):
    x=Conv2D(filters=filters, kernel_size=kernel_size,padding="same")(input_tensor)
    x=BatchNormalization()(x)
    x=Activation('relu')(x)
    x=MaxPooling2D(pool_size=(2,2))(x)
    x=Dropout(0.25)(x)
    return x

# %%
def Dense_f(input_tensor,nodes):
    x=Dense(nodes)(input_tensor)
    x=BatchNormalization()(x)
    x=Activation('relu')(x)
    x=Dropout(0.25)(x)
    return x

# %%
def model_fer(input_shape):
    inputs=Input(input_shape)
    conv_1=Convolution(inputs,32,(3,3))
    conv_2=Convolution(inputs,64,(5,5))
    conv_3=Convolution(inputs,128,(3,3))
    flatten=Flatten()(conv_3)
    dense_1=Dense_f(flatten,256)
    output=Dense(7,activation="softmax")(dense_1)
    model=Model(inputs=[inputs],outputs=[output])
    model.compile(loss=['categorical_crossentropy'],optimizer='adam', metrics=['accuracy'])
    return model

# %%
model=model_fer((48,48,1))
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\vnr_i\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\vnr_i\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From C:\Users\vnr_i\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 48, 48, 1)]       0
#
#  conv2d_2 (Conv2D)           (None, 48, 48, 128)       1280
#
#  batch_normalization_2 (Bat  (None, 48, 48, 128)       512
#  chNormalization)
#
#  activation_2 (Activation)   (None, 48, 48, 128)       0
#
#  max_pooling2d_2 (MaxPoolin  (None, 24, 24, 128)       0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 24, 24, 128)       0
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dense (Dense)               (None, 256)               18874624
#
#  batch_normalization_3 (Bat  (None, 256)               1024
#  chNormalization)
#
#  activation_3 (Activation)   (None, 256)               0
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 7)                 1799
#
# =================================================================
# Total params: 18879239 (72.02 MB)
# Trainable params: 18878471 (72.02 MB)
# Non-trainable params: 768 (3.00 KB)
# _________________________________________________________________

# %%
epochs=15
steps_per_epoch=train_generator.n//train_generator.batch_size
validation_steps=validation_generator.n//validation_generator.batch_size
checkpoint=ModelCheckpoint("model_weights.h5",monitor='val_accuracy', save_weights_only=True,mode='max',verbose=1)
callbacks=[checkpoint]

# %%
history=model.fit(
    x=train_generator,
    steps_per_epoch=steps_per_epoch,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=validation_steps,
    callbacks=callbacks)
# Out:
# Epoch 1/15
# WARNING:tensorflow:From C:\Users\vnr_i\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\vnr_i\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 448/448 [==============================] - ETA: 0s - loss: 1.6364 - accuracy: 0.3778
# Epoch 1: saving model to model_weights.h5
# 448/448 [==============================] - 920s 2s/step - loss: 1.6364 - accuracy: 0.3778 - val_loss: 1.4961 - val_accuracy: 0.4205
# Epoch 2/15
# 448/448 [==============================] - ETA: 0s - loss: 1.3381 - accuracy: 0.4937
# Epoch 2: saving model to model_weights.h5
# 448/448 [==============================] - 127s 284ms/step - loss: 1.3381 - accuracy: 0.4937 - val_loss: 1.5494 - val_accuracy: 0.4061
# Epoch 3/15
# 448/448 [==============================] - ETA: 0s - loss: 1.1811 - accuracy: 0.5575
# Epoch 3: saving model to model_weights.h5
# 448/448 [==============================] - 158s 354ms/step - loss: 1.1811 - accuracy: 0.5575 - val_loss: 1.4250 - val_accuracy: 0.4660
# Epoch 4/15
# 448/448 [==============================] - ETA: 0s - loss: 1.0484 - accuracy: 0.6123
# Epoch 4: saving model to model_weights.h5
# 448/448 [==============================] - 147s 327ms/step - loss: 1.0484 - accuracy: 0.6123 - val_loss: 1.5140 - val_accuracy: 0.4242
# Epoch 5/15
# 448/448 [==============================] - ETA: 0s - loss: 0.9317 - accuracy: 0.6622
# Epoch 5: saving model to model_weights.h5
# 448/448 [==============================] - 159s 356ms/step - loss: 0.9317 - accuracy: 0.6622 - val_loss: 1.5673 - val_accuracy: 0.4203
# Epoch 6/15
# 448/448 [==============================] - ETA: 0s - loss: 0.8009 - accuracy: 0.7139
# Epoch 6: saving model to model_weights.h5
# 448/448 [==============================] - 154s 343ms/step - loss: 0.8009 - accuracy: 0.7139 - val_loss: 1.6742 - val_accuracy: 0.4090
# Epoch 7/15
# 448/448 [==============================] - ETA: 0s - loss: 0.6860 - accuracy: 0.7564
# Epoch 7: saving model to model_weights.h5
# 448/448 [==============================] - 152s 339ms/step - loss: 0.6860 - accuracy: 0.7564 - val_loss: 1.5621 - val_accuracy: 0.4760
# Epoch 8/15
# 448/448 [==============================] - ETA: 0s - loss: 0.5873 - accuracy: 0.7950
# Epoch 8: saving model to model_weights.h5
# 448/448 [==============================] - 140s 311ms/step - loss: 0.5873 - accuracy: 0.7950 - val_loss: 1.6162 - val_accuracy: 0.4851
# Epoch 9/15
# 448/448 [==============================] - ETA: 0s - loss: 0.5106 - accuracy: 0.8214
# Epoch 9: saving model to model_weights.h5
# 448/448 [==============================] - 136s 304ms/step - loss: 0.5106 - accuracy: 0.8214 - val_loss: 1.6538 - val_accuracy: 0.4757
# Epoch 10/15
# 448/448 [==============================] - ETA: 0s - loss: 0.4349 - accuracy: 0.8481
# Epoch 10: saving model to model_weights.h5
# 448/448 [==============================] - 137s 307ms/step - loss: 0.4349 - accuracy: 0.8481 - val_loss: 1.8555 - val_accuracy: 0.4441
# Epoch 11/15
# 448/448 [==============================] - ETA: 0s - loss: 0.3812 - accuracy: 0.8694
# Epoch 11: saving model to model_weights.h5
# 448/448 [==============================] - 141s 314ms/step - loss: 0.3812 - accuracy: 0.8694 - val_loss: 1.7532 - val_accuracy: 0.4870
# Epoch 12/15
# 448/448 [==============================] - ETA: 0s - loss: 0.3360 - accuracy: 0.8895
# Epoch 12: saving model to model_weights.h5
# 448/448 [==============================] - 168s 375ms/step - loss: 0.3360 - accuracy: 0.8895 - val_loss: 1.9464 - val_accuracy: 0.4897
# Epoch 13/15
# 448/448 [==============================] - ETA: 0s - loss: 0.2925 - accuracy: 0.9019
# Epoch 13: saving model to model_weights.h5
# 448/448 [==============================] - 175s 391ms/step - loss: 0.2925 - accuracy: 0.9019 - val_loss: 1.9353 - val_accuracy: 0.4845
# Epoch 14/15
# 448/448 [==============================] - ETA: 0s - loss: 0.2623 - accuracy: 0.9143
# Epoch 14: saving model to model_weights.h5
# 448/448 [==============================] - 153s 342ms/step - loss: 0.2623 - accuracy: 0.9143 - val_loss: 2.1316 - val_accuracy: 0.4573
# Epoch 15/15
# 448/448 [==============================] - ETA: 0s - loss: 0.2463 - accuracy: 0.9183
# Epoch 15: saving model to model_weights.h5
# 448/448 [==============================] - 280s 625ms/step - loss: 0.2463 - accuracy: 0.9183 - val_loss: 2.0278 - val_accuracy: 0.4986

# %%
model.evaluate(validation_generator)
# Out:
# 113/113 [==============================] - 24s 211ms/step - loss: 2.0273 - accuracy: 0.4985
# [2.0273165702819824, 0.4985365867614746]

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.legend(['Train','Validation'],loc='upper left')
plt.subplots_adjust(top=1.0,bottom=0.0,right=0.95,left=0.0,hspace=0.25,wspace=0.35)

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.legend(['Train','Validation'],loc='upper left')
plt.subplots_adjust(top=1.0,bottom=0.0,right=0.95,left=0.0,hspace=0.25,wspace=0.35)

# %% [markdown]
# **Saving Model**

# %%
model_json=model.to_json()
with open("model_a.json","w") as json_file:
    json_file.write(model_json)
